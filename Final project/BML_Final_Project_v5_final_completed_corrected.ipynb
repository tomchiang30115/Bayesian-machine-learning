# %% [markdown]
# # CM50268 :: Final project (group work)
#
# **Total Marks 25 (25% of overall unit grade).**
#
# *Submission deadline: 8pm, May 10, 2022. Please submit this file along with your individual report in Moodle*

# %% [markdown]
# ## Submission & Marking
#
# This group exercise is assessed, and the marks will contribute to your final grade. For this exercise there are a number of places where you are expected to enter your own code. Please see the BML Final Project Specification document for details.
#
# Every place you have to add code is described in the text and specifically indicated by the comment:
#
# `#### **** YOUR CODE HERE **** ####`
#
#
# **Please submit your completed workbook using Moodle before 8pm on May 10, 2022 along with your individual report**. The workbook you submit must be this `.ipynb` file, which is saved into the directory you're running Jupyter; alternatively you can download it from the menu above using `File -> Download As -> Notebook (.ipynb)`. Remember to save your work regularly (Save and Checkpoint in the File menu, the icon of a floppy disk, or Ctrl-S); the version you submit should have all code blocks showing the results (if any) of execution below them.
#
# **You should take care to avoid any suggestion of plagiarism in your submission.** There is helpful information on how to avoid plagiarism on the University website: http://www.bath.ac.uk/library/help/infoguides/plagiarism.html

# %% [markdown]
# # Project setup
#
# This coursework involves the evaluation of Bayesian modelling methods on a real multivariate regression task. Please check the pdf file for the details of the project.
#
# - <font color=Red> Please try to use fixed random seeds to make your results reproducible </font>
#
# - <font color=Red> Please do NOT change the name of the fixed variables, as Task 2 - Task 5 of this coding exercises are auto-marked </font>
#
# The marks for Task 1 and Task 6 will be awarded based only on the content of the report.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from scipy import stats

import hmc_Lab as hmc
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from math import sqrt
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error

# %% [markdown]
# # Task 1 : Exploratory analysis (Section 4.1 in the specification doc)
#
# Undertake an initial exploratory analysis of the training data and summarise. Code in Task 1 will NOT by auto-marked. Results of Task 1 will be assessed along with your individual report, i.e., 4 marks in total.
#
#  - <font color=Red> Please perserve the variables `X_train` and  `y_train` representing the normalised data in numpy array, as required for the following exercises  </font>
#
#  - `X_train` is an np.array with shape (384, 9). The 1st column is a constant (bias) $x_0$ and the 2nd to the 9th columns are data variables $x_1,x_2,\dots,x_8$
#
#  - `y_train` is also an np.array with shape (384,), representing the target variable $y$

# %% [markdown]
# Undertake an initial exploratory analysis of the given data variables and summarise appropriately.
# This need not be particularly extensive, but it should demonstrate that you have undertaken some
# degree of \due diligence" with respect to the data set. In particular, you should focus on identifying
# which of the input variables (if any) might be expected to be useful for predicting heating load, and
# which might be irrelevant. You may also wish to comment on the apparent linearity, or otherwise,
# of the problem.
#
# As the final part of the exploratory analysis, establish a predictive \baseline" by fitting a linear
# model to the training set by least-squares, and assessing its prediction accuracy on both train and
# test sets.
#
# This section of your report should include:
#
# Initial observations as to the diculty of the task, its linearity etc.
#
# Your comment on the likely relevance of the variables for predicting \Heating Load"
#
# Appropriate graphs/charts as evidence to support the above
#
# Detail of the accuracy of the least-squares linear model, on both train and test sets, in terms
# of mean absolute error (MAE).

# %%
#### **** YOUR CODE HERE **** ####  
df_train = pd.read_csv('ee-train.csv')
df_test = pd.read_csv('ee-test.csv')

#### **** You can add extra cells to illustrate your results **** ####

# %%
df_train.head()
# Out:
#    const  Relative Compactness  Surface Area  Wall Area  Roof Area  \
# 0      1                  0.62         808.5      367.5      220.5
# 1      1                  0.90         563.5      318.5      122.5
# 2      1                  0.90         563.5      318.5      122.5
# 3      1                  0.79         637.0      343.0      147.0
# 4      1                  0.90         563.5      318.5      122.5
#
#    Overall Height  Orientation  Glazing Area  Glazing Area Distribution  \
# 0             3.5            3          0.10                          5
# 1             7.0            3          0.10                          2
# 2             7.0            3          0.40                          2
# 3             7.0            2          0.25                          2
# 4             7.0            4          0.40                          5
#
#    Heating Load
# 0         12.74
# 1         29.68
# 2         36.57
# 3         38.57
# 4         34.72

# %%
df_test.head()
# Out:
#    const  Relative Compactness  Surface Area  Wall Area  Roof Area  \
# 0      1                  0.98         514.5      294.0     110.25
# 1      1                  0.98         514.5      294.0     110.25
# 2      1                  0.90         563.5      318.5     122.50
# 3      1                  0.90         563.5      318.5     122.50
# 4      1                  0.86         588.0      294.0     147.00
#
#    Overall Height  Orientation  Glazing Area  Glazing Area Distribution  \
# 0             7.0            3           0.0                          0
# 1             7.0            4           0.0                          0
# 2             7.0            4           0.0                          0
# 3             7.0            5           0.0                          0
# 4             7.0            4           0.0                          0
#
#    Heating Load
# 0         15.55
# 1         15.55
# 2         20.71
# 3         19.68
# 4         19.34

# %%
df_train_corr = df_train.corr()

# %%
# sns.set_theme(style="white")

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(df_train_corr, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(10, 15))

# Draw the heatmap with the mask and correct aspect ratio
corr_hm = sns.heatmap(df_train_corr, mask=mask, cmap='coolwarm', vmax=1, vmin=-1, center=0,
            square=True, annot=True, linewidths=.1,  cbar_kws={'label': 'Correlation scale', 'shrink': 0.4})

corr_hm.set_title('Correlation matrix', size=30)
corr_hm.set_xlabel('Variables', fontsize = 20)
corr_hm.set_ylabel('Variables', fontsize = 20)
# Out:
# Text(69.0, 0.5, 'Variables')

# %%
sns.displot(df_train['Heating Load'], kde=False, bins=20).set(xlabel='Heating Load', ylabel='Count')
plt.title('Distribution of Heating Load values')
plt.tight_layout()
plt.show()

# %%
ss = StandardScaler()

train_ss = pd.DataFrame(ss.fit_transform(df_train), columns=df_train.columns)
test_ss = pd.DataFrame(ss.transform(df_test), columns=df_test.columns)

train_ss2 = pd.DataFrame(df_train, columns=df_train.columns)
test_ss2 = pd.DataFrame(df_test, columns=df_train.columns)

train_ss['const'] = 1
test_ss['const'] = 1

X_train = train_ss.drop('Heating Load', axis=1).values

y_train = train_ss2['Heating Load'].values
y_train_ss = train_ss['Heating Load'].values

Y_train = y_train
X_test = test_ss.drop('Heating Load', axis=1).values

y_test = test_ss2['Heating Load'].values
y_test_ss = test_ss['Heating Load'].values

# %%
import statsmodels.api as sm
OLS_Regression = sm.OLS(y_train, X_train).fit()
y_pred_train = OLS_Regression.predict(X_train)
y_pred_test = OLS_Regression.predict(X_test)
cov = OLS_Regression.cov_params()
std_pred = np.sqrt(np.diag(X_test @ cov @ X_test.T))

"""Plots the predictions and test, with the confidence interval."""
plt.subplots(figsize=(16,6))

plt.scatter(x=range(len(y_test)),
            y=y_test,
            label='Test Data')

plt.plot(y_pred_test,
            label='y Predictions')

plt.fill_between(x=range(len(y_pred_test)), 
                    y1=y_pred_test - 1.975 * std_pred, 
                    y2=y_pred_test + 1.975 * std_pred, 
                    label='95% Confidence')

plt.title('Ordinary Least Squares')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()

OLS_Regression.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.910
# Model:                            OLS   Adj. R-squared:                  0.909
# Method:                 Least Squares   F-statistic:                     544.8
# Date:                Sun, 15 May 2022   Prob (F-statistic):          1.72e-192
# Time:                        01:51:56   Log-Likelihood:                -968.22
# No. Observations:                 384   AIC:                             1952.
# Df Residuals:                     376   BIC:                             1984.
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         22.9207      0.155    147.581      0.000      22.615      23.226
# x1            -7.2346      1.654     -4.373      0.000     -10.488      -3.982
# x2            -3.9422      1.206     -3.269      0.001      -6.314      -1.571
# x3             0.7560      0.312      2.420      0.016       0.142       1.370
# x4            -4.2319      1.091     -3.880      0.000      -6.376      -2.087
# x5             7.2040      0.858      8.401      0.000       5.518       8.890
# x6            -0.1252      0.156     -0.803      0.423      -0.432       0.182
# x7             2.7702      0.162     17.129      0.000       2.452       3.088
# x8             0.2041      0.161      1.267      0.206      -0.113       0.521
# ==============================================================================
# Omnibus:                        7.903   Durbin-Watson:                   1.890
# Prob(Omnibus):                  0.019   Jarque-Bera (JB):               11.852
# Skew:                           0.109   Prob(JB):                      0.00267
# Kurtosis:                       3.832   Cond. No.                     1.93e+15
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 3.81e-28. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
print(f"MAE Train (blr): {mean_absolute_error(y_train, y_pred_train)}")
print(f"MAE Test (blr): {mean_absolute_error(y_test, y_pred_test)}")
# Out:
# MAE Train (blr): 2.1306794414069166
# MAE Test (blr): 2.069010093808354

# %%
# Check whether fixed variables are correctly defined ..
X_train = np.array(X_train)
y_train = np.array(y_train)

try:
    if not isinstance(X_train,np.ndarray):
        print('X_train should be an array')        
    if X_train.shape != (384,9):
        print('X_train is arranged in wrong shape')
except Exception as err:
    print('Error output:', err)
    
try:
    if not isinstance(y_train,np.ndarray):
        print('y_train should be an array')        
    if y_train.shape != (384,):
        print('y_train is arranged in wrong shape')
except Exception as err:
    print('Error output:', err)

# %% [markdown]
# #  Task 2 : Type-2 maximum likelihood (Section 4.2 (a) in the specification doc)
#
# ###  **(6 marks)**

# %% [markdown]
# Precisions are defined as: $\alpha = 1 / \sigma_w^2$ and $ \beta = 1 / \sigma_{\epsilon}^2 $
#
# Assume priors of $\alpha$ and $\beta$ follow flat Uniform distributions, please derive a likelihood function $(y|\alpha, \beta)$ (`compute_log_marginal`) to compute the *log-ikelihood* for the Bayesian linear regression problem using $X$ and hyperparameters $\alpha$ and $\beta$.
#
# In Lecture 4, slide 11 and 12 we have illustrated the equations of finding the most probable hyperparameters to maximise the likelihood with respect to the hyperparameters (slide 12).
#
#
# `X`: this is an np.array equivalent to matrix $X$ in the specification doc, e.g., `X_train`, `X_test`.
#
# `y`: this is an np.array equivalent totarget $y$ in the specification doc, e.g., `y_train`, `y_test`.

# %%
# Compute log-likelihood

def compute_log_marginal(X, y, alph, beta):
    
    cov = 1/beta * np.identity(X.shape[0]) + np.matmul(1/alph * X, X.T)
    lgp = stats.multivariate_normal.logpdf(y, cov=cov, allow_singular=True)
    
    return lgp

# %% [markdown]
# Compute log-evidence (marginal likelihood) `log_prob_y` and plot the 'contourf' of the log-posterior distribution.
#
# - The x-axis should be the value of $log \alpha$ and y-axis the $log\beta$, `log_prob_y` represents the log-evidence. For each axis, it is recommended to use
# `np.linspace(-5,0,100)`
#
# - It is strongly recommended that you use only natural logarithms for hyper-parameter scales. That is, you would use `numpy.exp()` and `numpy.log()` functions to convert (or to convert back) the logarithm terms.

# %%
#### **** YOUR CODE HERE **** ####   
log_alph = np.linspace(-5, 0, 100)
log_beta = np.linspace(-5, 0, 100)
log_prob_y = np.zeros([100,100])

for i in range(100):
    for j in range(100):
        a = np.exp(log_alph[i])
        r = np.exp(log_beta[j])
        log_prob_y[i,j] = compute_log_marginal(X_train, y_train, a, r)
        
# Check whether your variables are correctly defined ..
try:
    if not isinstance(log_prob_y,np.ndarray):
        print('log_prob_y should be an array')        
    if log_prob_y.shape != (100,100):
        print('log_prob_y is arranged in a wrong shape')
except Exception as err:
    print('Error output:', err)

# %% [markdown]
# Print out the most proboble values of the parameters $\alpha$ and $\beta$ and the corresponding log-likelihood value.

# %%
#### **** YOUR CODE HERE **** ####
x, y = np.unravel_index(np.argmax(log_prob_y), log_prob_y.shape)
max_alph = np.exp(log_alph[x])
max_beta = np.exp(log_beta[y])
# max_alph = log_alph[x]
# max_beta = log_beta[y]
max_log = log_prob_y.max()

print('Most Probable Alpha =', max_alph)
print('Log alpha =', np.log(max_alph))
print('Most Probable Beta =', max_beta)
print('Log Beta =', np.log(max_beta))
print(f'Max Log Marginal Likelihood = {max_log}')
# Out:
# Most Probable Alpha = 0.01174362845702136
# Log alpha = -4.444444444444445
# Most Probable Beta = 0.10836802322189586
# Log Beta = -2.2222222222222223
# Max Log Marginal Likelihood = -1001.4576252255187

# %% [markdown]
# Visualisation using `plt.contourf`for the posterior distribution and indicate the most probable value (with a highlighted marker) in the graph.

# %%
#### **** YOUR CODE HERE **** ####

plt.figure(figsize=(16, 8))
plt.contourf(log_alph, log_beta, log_prob_y.T)
#plt.plot(np.log10(max_alph), np.log10(max_beta), 'ro')
plt.plot(np.log(max_alph), np.log(max_beta), 'ro')
plt.annotate(r'log($\alpha)=$' + f'{np.log(max_alph):.2f}\n'+ r'log($\beta)=$' + 
             f'{np.log(max_beta):.2f}\n', (np.log(max_alph), np.log(max_beta)))
plt.xlabel('log alpha')
plt.ylabel('log beta')
plt.title('Log Marginal Likelihood')
plt.tight_layout()
plt.savefig('Log Marginal Likelihood.png')
plt.show()

# %% [markdown]
# Write a function `compute_posterior(X, y, alph, beta)`  to compute the posterior mean $\mathbf{\mu}$ (`Mu`) and covariance $\mathbf{\Sigma}$ (`SIGMA`) for the Bayesian linear regression model, and return `Mu` and `SIGMA` for the posterior in the np.array format.

# %%
def compute_posterior(X, y, alph, beta):
    #
    Mu = np.linalg.inv(X.T @ X + beta*alph*np.identity(X.shape[1])) @ X.T @ y
    SIGMA = beta * np.linalg.inv(X.T @ X + beta*alph*np.identity(X.shape[1]))
    #
    return Mu, SIGMA

# %% [markdown]
# Calculate the predicted weights and print out the corresponding RMSE for training and test sets.

# %%
#### **** YOUR CODE HERE **** ####

def predict(x_train, y_train, alph, beta, x_test):
    """Predict from the posterior."""
    w, mu = compute_posterior(x_train, y_train, alph, beta)
    y_pred = np.matmul(x_test, w)
    return y_pred, mu

y_pred_train, _ = predict(X_train, y_train, max_alph, max_beta, X_train)
y_pred_test, mu = predict(X_train, y_train, max_alph, max_beta, X_test)

alph = max_alph
beta = max_beta
Mu, SIGMA = compute_posterior(X_train, y_train, np.exp(alph), np.exp(beta))

err_train = mean_squared_error(y_train, y_pred_train)
err_test = mean_squared_error(y_test, y_pred_test)

# print(f'Maximum Predicted Weights for Train is {y_pred_train.max()} and Test is {y_pred_test.max()}')
# print(f'Minimum Predicted Weights for Train is {y_pred_train.min()} and Test is {y_pred_test.min()}')
# print()
RMSE_train = sqrt(mean_squared_error(y_train, y_pred_train))
print('RMSE for Training Sets is:', RMSE_train)
RMSE_test = sqrt(mean_squared_error(y_test, y_pred_test))
print('RMSE for Test Sets is:', RMSE_test)
print()
print(f"MAE Train (blr): {mean_absolute_error(y_train, y_pred_train)}")
print(f"MAE Test (blr): {mean_absolute_error(y_test, y_pred_test)}")
# Out:
# RMSE for Training Sets is: 3.011551809679531
# RMSE for Test Sets is: 2.843584066991447
#
# MAE Train (blr): 2.130668537392241
# MAE Test (blr): 2.0689837233886177

# %%
std_pred = np.sqrt(np.diag(X_test @ mu @ X_test.T))

plt.subplots(figsize=(16,6))

plt.scatter(x=range(len(y_test)),
            y=y_test,
            label='Test Data')

plt.plot(y_pred_test,
            label='y Predictions')

plt.fill_between(x=range(len(y_pred_test)), 
                    y1=y_pred_test - 1.975 * std_pred, 
                    y2=y_pred_test + 1.975 * std_pred, 
                    label='95% Confidence')

plt.title('Bayesian Linear Regression')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()

# %% [markdown]
# # Task 3: Variational Inference (Section 4.2 (b) in the specification doc)

# %% [markdown]
# ###  **(4 marks)**
#
# Write a Variational Inference function `VI(X_train, Y_train)` and return parameter estimates.
#
# The returned terms should include:
#
# `an`, `bn`, `cn`, `dn`: float
#
# `mn_n`: np.array, shape = (9,),
#
# `sig_n`: np.array, shape = (9,9),
#
# where
#
# `an` and `bn` are the hyper-parameters for $w\propto  N(w|0,\alpha)$,  $\alpha\propto Gamma(\alpha|a,b) $.
#
# `cn` and `dn` are the hyper-parameters for gaussian noise $N(0,\beta)$,  $\beta\propto Gamma(\beta|c,d) $.
#
# `mn_n` and `sig_n` are the mean $\mathbf{\mu}$ and covariance $\mathbf{\Sigma}$ of the posterior distribution w.r.t. $w$ (in this task) for the Bayesian linear regression model.
#
# The corresponding derivations should be completed in your report.

# %%
def VI(X_train, y_train):
    """Variational Inference"""

    # Initialise...
    a0,b0,c0,d0 = 1e-3,1e-3,1e-3,1e-3
    alpha0 = a0/b0
    beta0 = c0/d0
    mu_n, sig_n = compute_posterior(X_train, y_train, alpha0, beta0)
    an = a0 + 9/2
    cn = c0 + 384/2
    bn,dn = b0,d0
    
    for i in range(len(X_train)):
        bn = b0 + 1/2*(mu_n.T @ mu_n + np.trace(sig_n))
        dn = d0 + 1/2*((y_train - X_train @ mu_n).T @ (y_train - X_train @ mu_n))
        alphaN, betaN = an/bn, cn/dn
        mu_n, sig_n = compute_posterior(X_train, y_train, alphaN, betaN)
    
    return an, bn, cn, dn, mu_n, sig_n

an, bn, cn, dn, mu_n, sig_n = VI(X_train, y_train)

# %% [markdown]
# Print out the expectation of $\alpha$ and $\beta$ as `exp_alpha`,`exp_beta`.

# %%
try:
    an,bn,cn,dn, mu_n, sig_n = VI(X_train, Y_train)
except Exception as err:
    print('Error output:', err)
    
#### Print out the expectation of alpha and beta
#### **** YOUR CODE HERE **** ####

exp_alpha = an / bn
exp_beta = cn / dn

print(f"Expected alpha: {exp_alpha}")
print(f"Expected beta: {exp_beta}")
print(f"Expected log(alpha): {np.log(exp_alpha)}")
print(f"Expected log(beta): {np.log(exp_beta)}")
print(f"Best log probability: {compute_log_marginal(X_train, y_train, exp_alpha, exp_beta)}")
# Out:
# Expected alpha: 0.0119194030796849
# Expected beta: 0.11026084947934511
# Expected log(alpha): -4.4295876958064815
# Expected log(beta): -2.2049063615210094
# Best log probability: -1001.4975364847476

# %%
plt.figure(figsize=(16, 8))
plt.contourf(log_alph, log_beta, log_prob_y.T)
#plt.plot(np.log10(max_alph), np.log10(max_beta), 'ro')
plt.plot(np.log(max_alph), np.log(max_beta), 'ro')
plt.annotate(r'log($\alpha)=$' + f'{np.log(exp_alpha):.2f}\n'+ r'log($\beta)=$' + 
             f'{np.log(exp_beta):.2f}\n', (np.log(exp_alpha), np.log(exp_beta)))
plt.xlabel('log alpha')
plt.ylabel('log beta')
# Out:
# Text(0, 0.5, 'log beta')

# %%
# Check whether your variables are correctly defined  ..
try:
    if not isinstance(mu_n,np.ndarray):
        print('mu_n should be an array')        
    if mu_n.shape != (9,):
        print('mu_n is arranged in wrong shape')
except Exception as err:
    print('Error output:', err)
    
try:
    if not isinstance(sig_n,np.ndarray):
        print('sig_n should be an array')        
    if sig_n.shape != (9,9):
        print('sig_n is arranged in wrong shape')
except Exception as err:
    print('Error output:', err)
    
try:
    exp_alpha
    exp_beta
except Exception as err:
    print('Error output:', err)

# %% [markdown]
# Calculate the RMSE for training and test sets.

# %%
#### **** YOUR CODE HERE **** ####
rmse_train = sqrt(mean_squared_error(y_train, (X_train @ mu_n)))
rmse_test = sqrt(mean_squared_error(y_test, (X_test @ mu_n)))
mae_train = mean_absolute_error(y_train, (X_train @ mu_n))
mae_test = mean_absolute_error(y_test, (X_test @ mu_n))

print(f"Train RMSE (Variational Inference): {rmse_train}")
print(f"Test RMSE (Variational Inference): {rmse_test}")
print(f"Train MAE (Variational Inference): {mae_train}")
print(f"Test MAE (Variational Inference): {mae_test}")
# Out:
# Train RMSE (Variational Inference): 3.011551811142543
# Test RMSE (Variational Inference): 2.8435839388218858
# Train MAE (Variational Inference): 2.1306681809018593
# Test MAE (Variational Inference): 2.06898286155992

# %%
y_pred = X_test @ mu_n
std_pred = np.sqrt(np.diag(X_test @ sig_n @ X_test.T))


plt.subplots(figsize=(16,6))

plt.scatter(x=range(len(y_test)),
            y=y_test,
            label='Test Data')

plt.plot(y_pred,
            label='y Predictions')

plt.fill_between(x=range(len(y_pred)), 
                    y1=y_pred - 1.975 * std_pred, 
                    y2=y_pred + 1.975 * std_pred, 
                    label='95% Confidence')

plt.title('Variational Inference')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()

# %% [markdown]
# # Task 4: Verify HMC on a standard 2D Gaussian example (Section 4.3 in the specification doc)

# %% [markdown]
# ###  **(4 marks)**
#
# ## The "Distribution"
#
# Complete the following functions:
#
# - `energy_func(x)`: the energy function, return negative log pdf value in float format
# - `energy_grad(x)`: the gradient function returns a numpy array containing the partial derivatives of the energy function with respect to the parameters/hyper-parameters.
# - `covar`: Covariance matrix for 2-dimensional gaussian. It is an numpy array with shape (2,2), e.g,  np.array([[1.0875,1],[1,1.0875]])
#
# - `R`: the number of samples desired
# - `L`: number of simulation steps; for this simple case, 20 is easily enough
# - `eps`: simulation step length; set by trial-and-error to give approx. 90% acceptance
# - `burn`: simply set to `R/10`
# - `checkgrad`: set to true to test the consistency of `energy_func` and `energy_grad`

# %%
def energy_func(x, covar):
    #### **** YOUR CODE HERE **** ####
    neglpg = np.negative(stats.multivariate_normal.logpdf(x, cov=covar))
    return neglpg

def energy_grad(x, covar):
    #### **** YOUR CODE HERE **** ####
    g = np.linalg.inv(covar) @ x
    return g

# %% [markdown]
# ## Visualising the Distribution
# Before we run the sampler, let's visualise the distribution over an appropriate
# grid of values. Please specify `covar` to plot figures, an naive example of `covar` has been shown below

# %%
#### **** YOUR CODE BELOW **** ####

covar = np.array([[1.0875, 1],[1, 1.0875]])

#### **** YOUR CODE ABOVE **** ####

f = 5  # The "frequency" argument for the energy, used here to demonstrate how to use "args"
# Other plotting parameters
fsz = (10,8)
gsz = 100
lim = 3

# Setup the mesh grid

gx = np.linspace(-lim, lim, gsz)
GX, GY = np.meshgrid(gx, gx)
Gsz = GX.size
G = np.hstack((GX.reshape((Gsz, 1)), GY.reshape((Gsz, 1))))

# Plot the figure
plt.figure(figsize=fsz)
P = np.asarray([np.exp(-energy_func(g, covar)) for g in G])
plt.contour(GX, GY, P.reshape((gsz, gsz)), cmap='Reds', linewidths=3, zorder=1);

# %%
try:
    if not isinstance(covar ,np.ndarray):
        print('covar  should be an array')        
    if covar .shape != (2,2):
        print('covar  is arranged in wrong shape')
except Exception as err:
    print('Error output:', err)

# %%
# Initialise the state for the first time step
x0 = np.random.normal(size=2)

# Call the function from the pre-defined hmc module
hmc.gradient_check(x0, energy_func, energy_grad, covar)
# Out:
# Calc.         Numeric       Delta         Acc.
#      -3.9615       -3.9615   2.473577e-11  12
#      3.73241       3.73241  -8.271561e-11  11

# %% [markdown]
# ## Hyper-parameters
#
# Please tune optimal hyper-parameters incluidng `R`, `L`, and `eps` in the cell below.

# %%
np.random.seed(seed=1)  # Fix the random seed for better reproducibility

#### **** YOUR CODE BELOW **** ####

R= 5000
L = 20
eps = 0.36
burn = int(R/10) 

#### **** YOUR CODE ABOVE **** ####

# HMC sampling
S, *_ = hmc.sample(x0, energy_func, energy_grad, R, L, eps, burn=burn, checkgrad=True, args=[covar])
# Plot the figure
plt.figure(figsize=fsz)
plt.plot(S[:, 0], S[:, 1], '.', ms=6, color='CadetBlue', alpha=0.25, zorder=0)
plt.contour(GX, GY, P.reshape((gsz, gsz)), cmap='Reds', linewidths=3, zorder=1);
# Out:
# Calc.         Numeric       Delta         Acc.
#      -3.9615       -3.9615   2.473577e-11  12
#      3.73241       3.73241  -8.271561e-11  11
# |----------|  0% accepted [ 2 secs to go ]
# |#---------| 92% accepted [ 2 secs to go ]
# |##--------| 92% accepted [ 2 secs to go ]
# |###-------| 91% accepted [ 1 secs to go ]
# |####------| 91% accepted [ 1 secs to go ]
# |#####-----| 91% accepted [ 1 secs to go ]
# |######----| 90% accepted [ 1 secs to go ]
# |#######---| 90% accepted [ 1 secs to go ]
# |########--| 90% accepted [ 0 secs to go ]
# |#########-| 90% accepted [ 0 secs to go ]
# |##########| 90% accepted [ 0 secs to go ]
# HMC: R=5000 / L=20 / eps=0.36 / Accept=90.4%

# %%
#### **** YOUR CODE HERE **** ####
S_mean = np.cumsum(S,axis=0)/(np.array(range(len(S)))+1).reshape(-1,1)
fig, ax = plt.subplots(figsize=(10,6))
plt.plot(S_mean[:,0],label='Estimate for $\mu_1$')
plt.plot(S_mean[:,1],label='Estimate for $\mu_2$')

ax.set_xlabel('Number of Samples')
plt.title('Convergence of means')
plt.tight_layout()
#### **** You can add extra figures to support the individual report **** ####

# %% [markdown]
# # Task 5: Apply HMC to the Linear Regression Model (Section 4.4 in the specification doc)

# %% [markdown]
# ###  **(8 marks)**
#
# Complete the functions and the HMC code for this task:
#
# - `energy_func_lr(hps, x, y)`: where `hps` is a 2+9 dimension array, where the 1st dimension represents $\alpha$, and the 2nd represnets $\beta$. Thus, `hps[0]` should be the current $\alpha$, `hps[1]` the $\beta$ and `hps[2:]` represent the weights `w` for constant and 8 variables respectively. `x` and `y` is the x and y array of training data.
#
# - `energy_grad_lr(hps, x, y)`: the gradient function returns an array containing the partial derivatives of the energy function. should be the same shape for hps.
#
# - `R`: the number of samples desired
# - `L`: number of simulation steps; for this simple case, 20 is easily enough
# - `eps`: simulation step length; set by trial-and-error to give approx. 90% acceptance
# - `burn`: simply set to `R/10`
# - `checkgrad`: set to true to test the consistency of `energy_func` and `energy_grad`

# %%
def energy_func_lr(hps, x, y):
    #### **** YOUR CODE HERE **** ####
    alpha = hps[0]
    beta = hps[1]
    w = hps[2:]
    
    N, M = x.shape
    
    a = (N / 2 * np.log(beta)) - (N / 2 * np.log(2*np.pi)) - beta / 2 * (((y - x @ w).T @ (y - x @ w)))
    b = (M / 2 * np.log(alpha)) - (M / 2 * np.log(2*np.pi)) - (alpha / 2) * ((w.T @ w))
    
    neglgp = - (a + b)
    
    return neglgp

# %%
def energy_grad_lr(hps, x, y):
    
    #### **** YOUR CODE HERE **** ####
    alpha = hps[0]
    beta = hps[1]
    w = hps[2:]
    
    N, M = x.shape
    
    grad_alpha = - (M / (2 * alpha)) + ((w.T @ w) / 2)
    grad_beta = - (N / (2 * beta)) + ((((y - x @ w).T @ (y - x @ w))) / 2)
    grad_w = (alpha * w) - beta *  (y - x @ w) @ x
    
    g = np.array([grad_alpha, grad_beta] + list(grad_w))
    
    return g

# %%
np.random.seed(seed=1) 

#### **** YOUR CODE HERE **** ####

import warnings
warnings.filterwarnings('ignore')

R = 10000
burn = int(R/10) 
L = 100
eps = 0.0018
initial_alpha = 0.01
initial_beta = 0.1

hps = np.array([initial_alpha, initial_beta] + list(mu_n))

#### you can adjust the hpyer-parameters. 


S, *_ = hmc.sample(hps, energy_func_lr, energy_grad_lr, R, L, eps, burn=burn, checkgrad=True, args=[X_train, Y_train])
# Out:
# Calc.         Numeric       Delta         Acc.
#     -114.367      -114.367  -1.472493e-06   8
#     -178.667      -178.667  -1.131675e-07  10
#     0.226194      0.226194   2.855893e-08   7
#   -0.0713571     -0.071357   1.498632e-07   6
#    -0.038877     -0.038877   3.052152e-09   8
#   0.00746621    0.00746616  -5.056946e-08   6
#   -0.0417398    -0.0417398  -3.754352e-08   7
#    0.0711045     0.0711044  -5.071986e-08   7
#  -0.00123535   -0.00123532   3.366960e-08   5
#    0.0273382     0.0273382  -2.707042e-08   7
#   0.00201365    0.00201362  -2.479817e-08   5
# |----------|  0% accepted [ 21 secs to go ]
# |#---------| 97% accepted [ 19 secs to go ]
# |##--------| 97% accepted [ 18 secs to go ]
# |###-------| 97% accepted [ 15 secs to go ]
# |####------| 97% accepted [ 13 secs to go ]
# |#####-----| 97% accepted [ 11 secs to go ]
# |######----| 97% accepted [ 9 secs to go ]
# |#######---| 97% accepted [ 7 secs to go ]
# |########--| 97% accepted [ 4 secs to go ]
# |#########-| 97% accepted [ 2 secs to go ]
# |##########| 97% accepted [ 0 secs to go ]
# HMC: R=10000 / L=100 / eps=0.0018 / Accept=97.2%

# %% [markdown]
# ## Print out the RMSE and plot figures for your report

# %%
#### **** YOUR CODE HERE **** ####
S_mean = np.cumsum(S, axis=0) / (np.array(range(len(S))) + 1).reshape(-1,1)
fig, ax = plt.subplots(ncols=3, figsize=(20,6))
ax[0].plot(S_mean[:,0])
ax[0].set_xlabel('Number of Samples')
ax[0].set_ylabel(r'$\alpha$')
ax[0].set_title(r'$\alpha$')

ax[1].plot(S_mean[:,1])
ax[1].set_xlabel('Number of Samples')
ax[1].set_ylabel(r'$\beta$')
ax[1].set_title(r'$\beta$')

ax[2].plot(S_mean[:,-1])
ax[2].set_xlabel('Number of Samples')
ax[2].set_ylabel('Bias')
ax[2].set_title('Bias')

print(f"Expected Alpha: {S_mean[-1,0]}")
print(f"Expected Beta: {S_mean[-1,1]}")
print(f'Expected Bias = {S_mean[-1,-1]}')
# Out:
# Expected Alpha: 0.015012163299069937
# Expected Beta: 0.10861337585112496
# Expected Bias = 0.20480775170570908

# %%
S_mean = np.cumsum(S, axis=0) / (np.array(range(len(S))) + 1).reshape(-1,1)
best_w = S_mean[-1,2:]

rmse_train = sqrt(mean_squared_error(y_train, (X_train @ best_w)))
rmse_test = sqrt(mean_squared_error(y_test, (X_test @ best_w)))
mae_train = mean_absolute_error(y_train, (X_train @ best_w))
mae_test = mean_absolute_error(y_test, (X_test @ best_w))


print(f"RMSE Train (HMC): {rmse_train}")
print(f"RMSE Test (HMC): {rmse_test}")
print(f"MAE Train (HMC): {mae_train}")
print(f"MAE Test (HMC): {mae_test}")


y_pred = X_test @ best_w


plt.subplots(figsize=(16,6))

plt.scatter(x=range(len(y_test)),
            y=y_test,
            label='Test Data')

plt.plot(y_pred,
            label='y Predictions')

# plt.fill_between(x=range(len(y_pred)), 
#                     y1=y_pred - 1.975 * std_pred, 
#                     y2=y_pred + 1.975 * std_pred, 
#                     label='95% Confidence')

plt.title('Hamiltonian Monte Carlo')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
# Out:
# RMSE Train (HMC): 3.011649235829875
# RMSE Test (HMC): 2.8439323885773127
# MAE Train (HMC): 2.131793933192977
# MAE Test (HMC): 2.0705578678461425

# %% [markdown]
# # Task 6: Gaussian Processes
#
# ###  **(3 marks)**
#
# There's no restriction on the GP implementation, you could either use the sklearn package or the Tensorflow style, the latter of which may receive extra bonus mark depending on the quality of implementation.
#
# You only need to estimate the weights from $x0$ to $x8$ in this task, then calculate RMSE and plot supporting figures for your report.
#
# <font color=Red>  It is highly recommended that you impelment this part in a seperated file if your implementation contains too many extra libraries, as it may fool the auto-marker and incorrectly mark the rest of your notebook.
# <font>

# %%
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF, WhiteKernel, RationalQuadratic

def error_rms(t, y):
    """Compute RMS error for a prediction vector"""
    err = np.sqrt(np.mean((y - t) ** 2))
    return err

# %% [markdown]
# ### Gaussian Process Regressor

# %%
gpr = GaussianProcessRegressor()

gpr.fit(X_train, y_train)
acc = gpr.score(X_test, y_test)
log_prob = gpr.log_marginal_likelihood()
y_pred, std_pred = gpr.predict(X_test, return_std=True)
rmse_test = error_rms(y_test, y_pred)

mae_test = mean_absolute_error(y_test, y_pred)

print(f"R Score: {acc}")
print(f"RMSE Test (gp): {rmse_test}")
print(f"MAE Test (gp): {mae_test}")
print(f"% of MAE Test (gp): {mean_absolute_percentage_error(y_test, y_pred)}")
print(f"Log Marginal Liklihood: {log_prob:.2f}")


plt.subplots(figsize=(16,6))

plt.scatter(x=range(len(y_test)),
            y=y_test,
            label='Test Data')

plt.plot(y_pred,
            label='y Predictions')

plt.fill_between(x=range(len(y_pred)), 
                    y1=y_pred - 1.975 * std_pred, 
                    y2=y_pred + 1.975 * std_pred, 
                    label='95% Confidence')

plt.title('Gaussian Process (Default Kernel)')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# R Score: 0.9648203407156363
# RMSE Test (gp): 1.8900458253349346
# MAE Test (gp): 1.1677819263423632
# % of MAE Test (gp): 0.05300587831971712
# Log Marginal Liklihood: -17347.88

# %% [markdown]
# ### Gaussian Process Regressor with Rational Quadratic

# %%
gpr = GaussianProcessRegressor(kernel=1.0 * RationalQuadratic(length_scale=0.5, length_scale_bounds=(1e-3, 1e2)))

gpr.fit(X_train, y_train)
acc = gpr.score(X_test, y_test)
log_prob = gpr.log_marginal_likelihood()
y_pred, std_pred = gpr.predict(X_test, return_std=True)
rmse_test = error_rms(y_test, y_pred)

mae_test = mean_absolute_error(y_test, y_pred)

print(f"R Score: {acc}")
print(f"RMSE Test (gp w/ RQ): {rmse_test}")
print(f"MAE Test (gp w/ RQ): {mae_test}")
print(f"% of MAE Test (gp w/ RQ): {mean_absolute_percentage_error(y_test, y_pred)}")
print(f"Log Marginal Liklihood: {log_prob:.2f}")


plt.subplots(figsize=(16,6))

plt.scatter(x=range(len(y_test)),
            y=y_test,
            label='Test Data')

plt.plot(y_pred,
            label='y Predictions')

plt.fill_between(x=range(len(y_pred)), 
                    y1=y_pred - 1.975 * std_pred, 
                    y2=y_pred + 1.975 * std_pred, 
                    label='95% Confidence')

plt.title('Gaussian Process (Rational Quadratic Kernel)')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# R Score: 0.9922288978220385
# RMSE Test (gp w/ RQ): 0.888316704999718
# MAE Test (gp w/ RQ): 0.612581308396763
# % of MAE Test (gp w/ RQ): 0.03127067613544764
# Log Marginal Liklihood: -774.77

# %% [markdown]
# ### Gaussian Process Regressor with RBF

# %%
gpr = GaussianProcessRegressor(kernel=1.0 * RBF(length_scale=0.5, length_scale_bounds=(0.001, 100)))

gpr.fit(X_train, y_train)
acc = gpr.score(X_test, y_test)
log_prob = gpr.log_marginal_likelihood()
y_pred, std_pred = gpr.predict(X_test, return_std=True)
rmse_test = error_rms(y_test, y_pred)

mae_test = mean_absolute_error(y_test, y_pred)

print(f"R Score: {acc}")
print(f"RMSE Test (gp w/ rbf): {rmse_test}")
print(f"MAE Test (gp w/ rbf): {mae_test}")
print(f"% of MAE Test (gp w/ rbf): {mean_absolute_percentage_error(y_test, y_pred)}")

print(f"Log Marginal Liklihood: {log_prob:.2f}")


plt.subplots(figsize=(16,6))

plt.scatter(x=range(len(y_test)),
            y=y_test,
            label='Test Data')

plt.plot(y_pred,
            label='y Predictions')

plt.fill_between(x=range(len(y_pred)), 
                    y1=y_pred - 1.975 * std_pred, 
                    y2=y_pred + 1.975 * std_pred, 
                    label='95% Confidence')

plt.title('Gaussian Process with RBF')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# R Score: -0.17524613467654393
# RMSE Test (gp w/ rbf): 10.924232516393257
# MAE Test (gp w/ rbf): 8.312543062134372
# % of MAE Test (gp w/ rbf): 0.36799433312361973
# Log Marginal Liklihood: -60162.48

# %% [markdown]
# ### Gaussian Process Regressor with RBF and Noise

# %%
gpr = GaussianProcessRegressor(kernel=1.0 * RBF(length_scale=0.5, length_scale_bounds=(0.001, 100)) + WhiteKernel(
    noise_level=1e-4, noise_level_bounds=(1e-22, 1e2)))

gpr.fit(X_train, y_train)
acc = gpr.score(X_test, y_test)
log_prob = gpr.log_marginal_likelihood()
y_pred, std_pred = gpr.predict(X_test, return_std=True)
rmse_test = error_rms(y_test, y_pred)

mae_test = mean_absolute_error(y_test, y_pred)

print(f"R Score: {acc}")
print(f"RMSE Test (gp w/ rbf and noise): {rmse_test}")
print(f"MAE Test (gp w/ rbf and noise): {mae_test}")
print(f"% of MAE Test (gp w/ rbf and noise): {mean_absolute_percentage_error(y_test, y_pred)}")
print(f"Log Marginal Liklihood: {log_prob:.2f}")

plt.subplots(figsize=(16,6))

plt.scatter(x=range(len(y_test)),
            y=y_test,
            label='Test Data')

plt.plot(y_pred,
            label='y Predictions')

plt.fill_between(x=range(len(y_pred)), 
                    y1=y_pred - 1.975 * std_pred, 
                    y2=y_pred + 1.975 * std_pred, 
                    label='95% Confidence')

plt.title('Gaussian Process with RBF and Noise')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# R Score: 0.9955547194590422
# RMSE Test (gp w/ rbf and noise): 0.6718558557884639
# MAE Test (gp w/ rbf and noise): 0.502244661688745
# % of MAE Test (gp w/ rbf and noise): 0.029289792258009012
# Log Marginal Liklihood: -729.10

# %%
# !pip3 install gpytorch
import torch
import gpytorch
from gpytorch.mlls import DeepApproximateMLL
from gpytorch.models.deep_gps import DeepGPLayer, DeepGP
# Out:
# Requirement already satisfied: gpytorch in c:\users\ihsiu\.conda\envs\mynewenv3\lib\site-packages (1.6.0)

# %%
# We will use the simplest form of GP model, exact inference
class ExactGPModel(gpytorch.models.ExactGP):
    def __init__(self, X_train, y_train, likelihood):
        super(ExactGPModel, self).__init__(X_train, y_train, likelihood)
        self.mean_module = gpytorch.means.ConstantMean()
        self.covar_module = gpytorch.kernels.ScaleKernel(gpytorch.kernels.RBFKernel())
    
    def forward(self, x):
        mean_x = self.mean_module(x)
        covar_x = self.covar_module(x)
        return gpytorch.distributions.MultivariateNormal(mean_x, covar_x)

# initialize likelihood and model
GP_X_train = torch.from_numpy(np.array(X_train))
GP_y_train = torch.from_numpy(np.array(y_train))
likelihood = gpytorch.likelihoods.GaussianLikelihood()
model = ExactGPModel(GP_X_train, GP_y_train, likelihood)

# %%
model.state_dict()
# Out:
# OrderedDict([('likelihood.noise_covar.raw_noise', tensor([0.])),
#              ('likelihood.noise_covar.raw_noise_constraint.lower_bound',
#               tensor(1.0000e-04)),
#              ('likelihood.noise_covar.raw_noise_constraint.upper_bound',
#               tensor(inf)),
#              ('mean_module.constant', tensor([0.])),
#              ('covar_module.raw_outputscale', tensor(0.)),
#              ('covar_module.base_kernel.raw_lengthscale', tensor([[0.]])),
#              ('covar_module.base_kernel.raw_lengthscale_constraint.lower_bound',
#               tensor(0.)),
#              ('covar_module.base_kernel.raw_lengthscale_constraint.upper_bound',
#               tensor(inf)),
#              ('covar_module.raw_outputscale_constraint.lower_bound',
#               tensor(0.)),
#              ('covar_module.raw_outputscale_constraint.upper_bound',
#               tensor(inf))])

# %%
training_iter = 384

# Find optimal model hyperparameters
model.train()
likelihood.train()

# Use the adam optimizer
optimizer = torch.optim.Adam([
    {'params': model.parameters()},  # Includes GaussianLikelihood parameters
], lr=0.1)

# "Loss" for GPs - the marginal log likelihood
mll = gpytorch.mlls.ExactMarginalLogLikelihood(likelihood, model)
loss_arr = []
for i in range(training_iter):
    # Zero gradients from previous iteration
    optimizer.zero_grad()
    # Output from model
    output = model(GP_X_train)
    # Calc loss and backprop gradients
    loss = -mll(output, GP_y_train)
    loss.backward()
    loss_arr.append(loss)
    print('Iter %d/%d - Loss: %.3f   lengthscale: %.3f   noise: %.3f' % (
        i + 1, training_iter, loss.item(),
        model.covar_module.base_kernel.lengthscale.item(),
        model.likelihood.noise.item()
    ))
    optimizer.step()
# Out:
# Iter 1/384 - Loss: 85.114   lengthscale: 0.693   noise: 0.693
# Iter 2/384 - Loss: 68.769   lengthscale: 0.744   noise: 0.744
# Iter 3/384 - Loss: 55.840   lengthscale: 0.798   noise: 0.797
# Iter 4/384 - Loss: 45.709   lengthscale: 0.852   noise: 0.851
# Iter 5/384 - Loss: 37.809   lengthscale: 0.907   noise: 0.904
# Iter 6/384 - Loss: 31.653   lengthscale: 0.963   noise: 0.957
# Iter 7/384 - Loss: 26.845   lengthscale: 1.018   noise: 1.009
# Iter 8/384 - Loss: 23.071   lengthscale: 1.073   noise: 1.061
# Iter 9/384 - Loss: 20.088   lengthscale: 1.126   noise: 1.110
# Iter 10/384 - Loss: 17.711   lengthscale: 1.179   noise: 1.158
# Iter 11/384 - Loss: 15.801   lengthscale: 1.229   noise: 1.205
# Iter 12/384 - Loss: 14.251   lengthscale: 1.278   noise: 1.250
# Iter 13/384 - Loss: 12.982   lengthscale: 1.325   noise: 1.294
# Iter 14/384 - Loss: 11.934   lengthscale: 1.370   noise: 1.335
# Iter 15/384 - Loss: 11.061   lengthscale: 1.413   noise: 1.376
# Iter 16/384 - Loss: 10.327   lengthscale: 1.455   noise: 1.414
# Iter 17/384 - Loss: 9.706   lengthscale: 1.494   noise: 1.452
# Iter 18/384 - Loss: 9.175   lengthscale: 1.531   noise: 1.488
# Iter 19/384 - Loss: 8.720   lengthscale: 1.567   noise: 1.522
# Iter 20/384 - Loss: 8.326   lengthscale: 1.600   noise: 1.555
# Iter 21/384 - Loss: 7.983   lengthscale: 1.632   noise: 1.587
# Iter 22/384 - Loss: 7.682   lengthscale: 1.662   noise: 1.618
# Iter 23/384 - Loss: 7.418   lengthscale: 1.691   noise: 1.647
# Iter 24/384 - Loss: 7.184   lengthscale: 1.718   noise: 1.676
# Iter 25/384 - Loss: 6.976   lengthscale: 1.744   noise: 1.703
# Iter 26/384 - Loss: 6.790   lengthscale: 1.768   noise: 1.730
# Iter 27/384 - Loss: 6.623   lengthscale: 1.791   noise: 1.756
# Iter 28/384 - Loss: 6.473   lengthscale: 1.812   noise: 1.781
# Iter 29/384 - Loss: 6.337   lengthscale: 1.833   noise: 1.805
# Iter 30/384 - Loss: 6.214   lengthscale: 1.853   noise: 1.828
# Iter 31/384 - Loss: 6.101   lengthscale: 1.871   noise: 1.851
# Iter 32/384 - Loss: 5.998   lengthscale: 1.889   noise: 1.873
# Iter 33/384 - Loss: 5.903   lengthscale: 1.905   noise: 1.894
# Iter 34/384 - Loss: 5.816   lengthscale: 1.921   noise: 1.915
# Iter 35/384 - Loss: 5.736   lengthscale: 1.936   noise: 1.936
# Iter 36/384 - Loss: 5.661   lengthscale: 1.950   noise: 1.956
# Iter 37/384 - Loss: 5.592   lengthscale: 1.964   noise: 1.975
# Iter 38/384 - Loss: 5.528   lengthscale: 1.977   noise: 1.994
# Iter 39/384 - Loss: 5.468   lengthscale: 1.989   noise: 2.012
# Iter 40/384 - Loss: 5.411   lengthscale: 2.001   noise: 2.031
# Iter 41/384 - Loss: 5.358   lengthscale: 2.012   noise: 2.048
# Iter 42/384 - Loss: 5.308   lengthscale: 2.023   noise: 2.066
# Iter 43/384 - Loss: 5.261   lengthscale: 2.033   noise: 2.083
# Iter 44/384 - Loss: 5.217   lengthscale: 2.043   noise: 2.100
# Iter 45/384 - Loss: 5.175   lengthscale: 2.053   noise: 2.117
# Iter 46/384 - Loss: 5.135   lengthscale: 2.062   noise: 2.133
# Iter 47/384 - Loss: 5.096   lengthscale: 2.071   noise: 2.149
# Iter 48/384 - Loss: 5.060   lengthscale: 2.079   noise: 2.165
# Iter 49/384 - Loss: 5.025   lengthscale: 2.087   noise: 2.181
# Iter 50/384 - Loss: 4.992   lengthscale: 2.095   noise: 2.196
# Iter 51/384 - Loss: 4.960   lengthscale: 2.103   noise: 2.212
# Iter 52/384 - Loss: 4.930   lengthscale: 2.110   noise: 2.227
# Iter 53/384 - Loss: 4.900   lengthscale: 2.118   noise: 2.242
# Iter 54/384 - Loss: 4.872   lengthscale: 2.125   noise: 2.257
# Iter 55/384 - Loss: 4.845   lengthscale: 2.132   noise: 2.271
# Iter 56/384 - Loss: 4.818   lengthscale: 2.138   noise: 2.286
# Iter 57/384 - Loss: 4.792   lengthscale: 2.145   noise: 2.300
# Iter 58/384 - Loss: 4.768   lengthscale: 2.151   noise: 2.315
# Iter 59/384 - Loss: 4.744   lengthscale: 2.157   noise: 2.329
# Iter 60/384 - Loss: 4.720   lengthscale: 2.164   noise: 2.343
# Iter 61/384 - Loss: 4.698   lengthscale: 2.170   noise: 2.357
# Iter 62/384 - Loss: 4.676   lengthscale: 2.175   noise: 2.371
# Iter 63/384 - Loss: 4.654   lengthscale: 2.181   noise: 2.385
# Iter 64/384 - Loss: 4.633   lengthscale: 2.187   noise: 2.399
# Iter 65/384 - Loss: 4.613   lengthscale: 2.192   noise: 2.412
# Iter 66/384 - Loss: 4.593   lengthscale: 2.198   noise: 2.426
# Iter 67/384 - Loss: 4.574   lengthscale: 2.203   noise: 2.439
# Iter 68/384 - Loss: 4.555   lengthscale: 2.209   noise: 2.453
# Iter 69/384 - Loss: 4.536   lengthscale: 2.214   noise: 2.466
# Iter 70/384 - Loss: 4.518   lengthscale: 2.219   noise: 2.479
# Iter 71/384 - Loss: 4.500   lengthscale: 2.224   noise: 2.492
# Iter 72/384 - Loss: 4.482   lengthscale: 2.229   noise: 2.505
# Iter 73/384 - Loss: 4.465   lengthscale: 2.234   noise: 2.519
# Iter 74/384 - Loss: 4.449   lengthscale: 2.239   noise: 2.532
# Iter 75/384 - Loss: 4.432   lengthscale: 2.244   noise: 2.544
# Iter 76/384 - Loss: 4.416   lengthscale: 2.249   noise: 2.557
# Iter 77/384 - Loss: 4.400   lengthscale: 2.254   noise: 2.570
# Iter 78/384 - Loss: 4.384   lengthscale: 2.258   noise: 2.583
# Iter 79/384 - Loss: 4.369   lengthscale: 2.263   noise: 2.596
# Iter 80/384 - Loss: 4.354   lengthscale: 2.268   noise: 2.608
# Iter 81/384 - Loss: 4.339   lengthscale: 2.272   noise: 2.621
# Iter 82/384 - Loss: 4.325   lengthscale: 2.277   noise: 2.633
# Iter 83/384 - Loss: 4.310   lengthscale: 2.282   noise: 2.646
# Iter 84/384 - Loss: 4.296   lengthscale: 2.286   noise: 2.658
# Iter 85/384 - Loss: 4.282   lengthscale: 2.291   noise: 2.671
# Iter 86/384 - Loss: 4.269   lengthscale: 2.295   noise: 2.683
# Iter 87/384 - Loss: 4.255   lengthscale: 2.300   noise: 2.695
# Iter 88/384 - Loss: 4.242   lengthscale: 2.304   noise: 2.707
# Iter 89/384 - Loss: 4.229   lengthscale: 2.308   noise: 2.720
# Iter 90/384 - Loss: 4.216   lengthscale: 2.313   noise: 2.732
# Iter 91/384 - Loss: 4.203   lengthscale: 2.317   noise: 2.744
# Iter 92/384 - Loss: 4.191   lengthscale: 2.321   noise: 2.756
# Iter 93/384 - Loss: 4.178   lengthscale: 2.326   noise: 2.768
# Iter 94/384 - Loss: 4.166   lengthscale: 2.330   noise: 2.780
# Iter 95/384 - Loss: 4.154   lengthscale: 2.334   noise: 2.792
# Iter 96/384 - Loss: 4.143   lengthscale: 2.338   noise: 2.803
# Iter 97/384 - Loss: 4.131   lengthscale: 2.342   noise: 2.815
# Iter 98/384 - Loss: 4.119   lengthscale: 2.347   noise: 2.827
# Iter 99/384 - Loss: 4.108   lengthscale: 2.351   noise: 2.839
# Iter 100/384 - Loss: 4.097   lengthscale: 2.355   noise: 2.850
# Iter 101/384 - Loss: 4.086   lengthscale: 2.359   noise: 2.862
# Iter 102/384 - Loss: 4.075   lengthscale: 2.363   noise: 2.874
# Iter 103/384 - Loss: 4.064   lengthscale: 2.367   noise: 2.885
# Iter 104/384 - Loss: 4.054   lengthscale: 2.371   noise: 2.897
# Iter 105/384 - Loss: 4.043   lengthscale: 2.375   noise: 2.908
# Iter 106/384 - Loss: 4.033   lengthscale: 2.379   noise: 2.919
# Iter 107/384 - Loss: 4.023   lengthscale: 2.383   noise: 2.931
# Iter 108/384 - Loss: 4.013   lengthscale: 2.387   noise: 2.942
# Iter 109/384 - Loss: 4.003   lengthscale: 2.391   noise: 2.953
# Iter 110/384 - Loss: 3.993   lengthscale: 2.395   noise: 2.964
# Iter 111/384 - Loss: 3.983   lengthscale: 2.399   noise: 2.976
# Iter 112/384 - Loss: 3.974   lengthscale: 2.403   noise: 2.987
# Iter 113/384 - Loss: 3.964   lengthscale: 2.406   noise: 2.998
# Iter 114/384 - Loss: 3.955   lengthscale: 2.410   noise: 3.009
# Iter 115/384 - Loss: 3.946   lengthscale: 2.414   noise: 3.020
# Iter 116/384 - Loss: 3.937   lengthscale: 2.418   noise: 3.031
# Iter 117/384 - Loss: 3.928   lengthscale: 2.422   noise: 3.042
# Iter 118/384 - Loss: 3.919   lengthscale: 2.425   noise: 3.053
# Iter 119/384 - Loss: 3.910   lengthscale: 2.429   noise: 3.063
# Iter 120/384 - Loss: 3.902   lengthscale: 2.433   noise: 3.074
# Iter 121/384 - Loss: 3.893   lengthscale: 2.436   noise: 3.085
# Iter 122/384 - Loss: 3.885   lengthscale: 2.440   noise: 3.096
# Iter 123/384 - Loss: 3.876   lengthscale: 2.444   noise: 3.106
# Iter 124/384 - Loss: 3.868   lengthscale: 2.447   noise: 3.117
# Iter 125/384 - Loss: 3.860   lengthscale: 2.451   noise: 3.128
# Iter 126/384 - Loss: 3.852   lengthscale: 2.455   noise: 3.138
# Iter 127/384 - Loss: 3.844   lengthscale: 2.458   noise: 3.149
# Iter 128/384 - Loss: 3.836   lengthscale: 2.462   noise: 3.159
# Iter 129/384 - Loss: 3.828   lengthscale: 2.465   noise: 3.169
# Iter 130/384 - Loss: 3.821   lengthscale: 2.469   noise: 3.180
# Iter 131/384 - Loss: 3.813   lengthscale: 2.473   noise: 3.190
# Iter 132/384 - Loss: 3.805   lengthscale: 2.476   noise: 3.201
# Iter 133/384 - Loss: 3.798   lengthscale: 2.480   noise: 3.211
# Iter 134/384 - Loss: 3.791   lengthscale: 2.483   noise: 3.221
# Iter 135/384 - Loss: 3.783   lengthscale: 2.487   noise: 3.231
# Iter 136/384 - Loss: 3.776   lengthscale: 2.490   noise: 3.241
# Iter 137/384 - Loss: 3.769   lengthscale: 2.493   noise: 3.251
# Iter 138/384 - Loss: 3.762   lengthscale: 2.497   noise: 3.262
# Iter 139/384 - Loss: 3.755   lengthscale: 2.500   noise: 3.272
# Iter 140/384 - Loss: 3.748   lengthscale: 2.504   noise: 3.282
# Iter 141/384 - Loss: 3.741   lengthscale: 2.507   noise: 3.292
# Iter 142/384 - Loss: 3.735   lengthscale: 2.510   noise: 3.301
# Iter 143/384 - Loss: 3.728   lengthscale: 2.514   noise: 3.311
# Iter 144/384 - Loss: 3.721   lengthscale: 2.517   noise: 3.321
# Iter 145/384 - Loss: 3.715   lengthscale: 2.520   noise: 3.331
# Iter 146/384 - Loss: 3.709   lengthscale: 2.524   noise: 3.341
# Iter 147/384 - Loss: 3.702   lengthscale: 2.527   noise: 3.351
# Iter 148/384 - Loss: 3.696   lengthscale: 2.530   noise: 3.360
# Iter 149/384 - Loss: 3.690   lengthscale: 2.534   noise: 3.370
# Iter 150/384 - Loss: 3.683   lengthscale: 2.537   noise: 3.380
# Iter 151/384 - Loss: 3.677   lengthscale: 2.540   noise: 3.389
# Iter 152/384 - Loss: 3.671   lengthscale: 2.543   noise: 3.399
# Iter 153/384 - Loss: 3.665   lengthscale: 2.546   noise: 3.408
# Iter 154/384 - Loss: 3.659   lengthscale: 2.550   noise: 3.418
# Iter 155/384 - Loss: 3.653   lengthscale: 2.553   noise: 3.427
# Iter 156/384 - Loss: 3.648   lengthscale: 2.556   noise: 3.437
# Iter 157/384 - Loss: 3.642   lengthscale: 2.559   noise: 3.446
# Iter 158/384 - Loss: 3.636   lengthscale: 2.562   noise: 3.455
# Iter 159/384 - Loss: 3.631   lengthscale: 2.565   noise: 3.465
# Iter 160/384 - Loss: 3.625   lengthscale: 2.568   noise: 3.474
# Iter 161/384 - Loss: 3.620   lengthscale: 2.572   noise: 3.483
# Iter 162/384 - Loss: 3.614   lengthscale: 2.575   noise: 3.493
# Iter 163/384 - Loss: 3.609   lengthscale: 2.578   noise: 3.502
# Iter 164/384 - Loss: 3.603   lengthscale: 2.581   noise: 3.511
# Iter 165/384 - Loss: 3.598   lengthscale: 2.584   noise: 3.520
# Iter 166/384 - Loss: 3.593   lengthscale: 2.587   noise: 3.529
# Iter 167/384 - Loss: 3.588   lengthscale: 2.590   noise: 3.538
# Iter 168/384 - Loss: 3.582   lengthscale: 2.593   noise: 3.547
# Iter 169/384 - Loss: 3.577   lengthscale: 2.596   noise: 3.556
# Iter 170/384 - Loss: 3.572   lengthscale: 2.599   noise: 3.565
# Iter 171/384 - Loss: 3.567   lengthscale: 2.602   noise: 3.574
# Iter 172/384 - Loss: 3.562   lengthscale: 2.605   noise: 3.583
# Iter 173/384 - Loss: 3.557   lengthscale: 2.608   noise: 3.592
# Iter 174/384 - Loss: 3.553   lengthscale: 2.611   noise: 3.601
# Iter 175/384 - Loss: 3.548   lengthscale: 2.614   noise: 3.610
# Iter 176/384 - Loss: 3.543   lengthscale: 2.616   noise: 3.618
# Iter 177/384 - Loss: 3.538   lengthscale: 2.619   noise: 3.627
# Iter 178/384 - Loss: 3.534   lengthscale: 2.622   noise: 3.636
# Iter 179/384 - Loss: 3.529   lengthscale: 2.625   noise: 3.644
# Iter 180/384 - Loss: 3.524   lengthscale: 2.628   noise: 3.653
# Iter 181/384 - Loss: 3.520   lengthscale: 2.631   noise: 3.662
# Iter 182/384 - Loss: 3.515   lengthscale: 2.634   noise: 3.670
# Iter 183/384 - Loss: 3.511   lengthscale: 2.636   noise: 3.679
# Iter 184/384 - Loss: 3.506   lengthscale: 2.639   noise: 3.687
# Iter 185/384 - Loss: 3.502   lengthscale: 2.642   noise: 3.696
# Iter 186/384 - Loss: 3.498   lengthscale: 2.645   noise: 3.704
# Iter 187/384 - Loss: 3.493   lengthscale: 2.648   noise: 3.713
# Iter 188/384 - Loss: 3.489   lengthscale: 2.650   noise: 3.721
# Iter 189/384 - Loss: 3.485   lengthscale: 2.653   noise: 3.730
# Iter 190/384 - Loss: 3.481   lengthscale: 2.656   noise: 3.738
# Iter 191/384 - Loss: 3.477   lengthscale: 2.659   noise: 3.746
# Iter 192/384 - Loss: 3.472   lengthscale: 2.661   noise: 3.755
# Iter 193/384 - Loss: 3.468   lengthscale: 2.664   noise: 3.763
# Iter 194/384 - Loss: 3.464   lengthscale: 2.667   noise: 3.771
# Iter 195/384 - Loss: 3.460   lengthscale: 2.669   noise: 3.780
# Iter 196/384 - Loss: 3.456   lengthscale: 2.672   noise: 3.788
# Iter 197/384 - Loss: 3.452   lengthscale: 2.675   noise: 3.796
# Iter 198/384 - Loss: 3.448   lengthscale: 2.677   noise: 3.804
# Iter 199/384 - Loss: 3.445   lengthscale: 2.680   noise: 3.812
# Iter 200/384 - Loss: 3.441   lengthscale: 2.683   noise: 3.820
# Iter 201/384 - Loss: 3.437   lengthscale: 2.685   noise: 3.828
# Iter 202/384 - Loss: 3.433   lengthscale: 2.688   noise: 3.836
# Iter 203/384 - Loss: 3.429   lengthscale: 2.691   noise: 3.844
# Iter 204/384 - Loss: 3.426   lengthscale: 2.693   noise: 3.852
# Iter 205/384 - Loss: 3.422   lengthscale: 2.696   noise: 3.860
# Iter 206/384 - Loss: 3.418   lengthscale: 2.698   noise: 3.868
# Iter 207/384 - Loss: 3.415   lengthscale: 2.701   noise: 3.876
# Iter 208/384 - Loss: 3.411   lengthscale: 2.703   noise: 3.884
# Iter 209/384 - Loss: 3.408   lengthscale: 2.706   noise: 3.892
# Iter 210/384 - Loss: 3.404   lengthscale: 2.708   noise: 3.900
# Iter 211/384 - Loss: 3.401   lengthscale: 2.711   noise: 3.908
# Iter 212/384 - Loss: 3.397   lengthscale: 2.713   noise: 3.915
# Iter 213/384 - Loss: 3.394   lengthscale: 2.716   noise: 3.923
# Iter 214/384 - Loss: 3.390   lengthscale: 2.718   noise: 3.931
# Iter 215/384 - Loss: 3.387   lengthscale: 2.721   noise: 3.939
# Iter 216/384 - Loss: 3.383   lengthscale: 2.723   noise: 3.946
# Iter 217/384 - Loss: 3.380   lengthscale: 2.726   noise: 3.954
# Iter 218/384 - Loss: 3.377   lengthscale: 2.728   noise: 3.962
# Iter 219/384 - Loss: 3.374   lengthscale: 2.731   noise: 3.969
# Iter 220/384 - Loss: 3.370   lengthscale: 2.733   noise: 3.977
# Iter 221/384 - Loss: 3.367   lengthscale: 2.736   noise: 3.984
# Iter 222/384 - Loss: 3.364   lengthscale: 2.738   noise: 3.992
# Iter 223/384 - Loss: 3.361   lengthscale: 2.740   noise: 3.999
# Iter 224/384 - Loss: 3.358   lengthscale: 2.743   noise: 4.007
# Iter 225/384 - Loss: 3.354   lengthscale: 2.745   noise: 4.014
# Iter 226/384 - Loss: 3.351   lengthscale: 2.747   noise: 4.022
# Iter 227/384 - Loss: 3.348   lengthscale: 2.750   noise: 4.029
# Iter 228/384 - Loss: 3.345   lengthscale: 2.752   noise: 4.037
# Iter 229/384 - Loss: 3.342   lengthscale: 2.755   noise: 4.044
# Iter 230/384 - Loss: 3.339   lengthscale: 2.757   noise: 4.051
# Iter 231/384 - Loss: 3.336   lengthscale: 2.759   noise: 4.059
# Iter 232/384 - Loss: 3.333   lengthscale: 2.762   noise: 4.066
# Iter 233/384 - Loss: 3.330   lengthscale: 2.764   noise: 4.073
# Iter 234/384 - Loss: 3.327   lengthscale: 2.766   noise: 4.081
# Iter 235/384 - Loss: 3.324   lengthscale: 2.768   noise: 4.088
# Iter 236/384 - Loss: 3.322   lengthscale: 2.771   noise: 4.095
# Iter 237/384 - Loss: 3.319   lengthscale: 2.773   noise: 4.102
# Iter 238/384 - Loss: 3.316   lengthscale: 2.775   noise: 4.110
# Iter 239/384 - Loss: 3.313   lengthscale: 2.777   noise: 4.117
# Iter 240/384 - Loss: 3.310   lengthscale: 2.780   noise: 4.124
# Iter 241/384 - Loss: 3.307   lengthscale: 2.782   noise: 4.131
# Iter 242/384 - Loss: 3.305   lengthscale: 2.784   noise: 4.138
# Iter 243/384 - Loss: 3.302   lengthscale: 2.786   noise: 4.145
# Iter 244/384 - Loss: 3.299   lengthscale: 2.789   noise: 4.152
# Iter 245/384 - Loss: 3.297   lengthscale: 2.791   noise: 4.159
# Iter 246/384 - Loss: 3.294   lengthscale: 2.793   noise: 4.166
# Iter 247/384 - Loss: 3.291   lengthscale: 2.795   noise: 4.173
# Iter 248/384 - Loss: 3.289   lengthscale: 2.797   noise: 4.180
# Iter 249/384 - Loss: 3.286   lengthscale: 2.800   noise: 4.187
# Iter 250/384 - Loss: 3.283   lengthscale: 2.802   noise: 4.194
# Iter 251/384 - Loss: 3.281   lengthscale: 2.804   noise: 4.201
# Iter 252/384 - Loss: 3.278   lengthscale: 2.806   noise: 4.208
# Iter 253/384 - Loss: 3.276   lengthscale: 2.808   noise: 4.215
# Iter 254/384 - Loss: 3.273   lengthscale: 2.810   noise: 4.222
# Iter 255/384 - Loss: 3.271   lengthscale: 2.812   noise: 4.228
# Iter 256/384 - Loss: 3.268   lengthscale: 2.815   noise: 4.235
# Iter 257/384 - Loss: 3.266   lengthscale: 2.817   noise: 4.242
# Iter 258/384 - Loss: 3.263   lengthscale: 2.819   noise: 4.249
# Iter 259/384 - Loss: 3.261   lengthscale: 2.821   noise: 4.256
# Iter 260/384 - Loss: 3.258   lengthscale: 2.823   noise: 4.262
# Iter 261/384 - Loss: 3.256   lengthscale: 2.825   noise: 4.269
# Iter 262/384 - Loss: 3.254   lengthscale: 2.827   noise: 4.276
# Iter 263/384 - Loss: 3.251   lengthscale: 2.829   noise: 4.282
# Iter 264/384 - Loss: 3.249   lengthscale: 2.831   noise: 4.289
# Iter 265/384 - Loss: 3.247   lengthscale: 2.833   noise: 4.296
# Iter 266/384 - Loss: 3.244   lengthscale: 2.835   noise: 4.302
# Iter 267/384 - Loss: 3.242   lengthscale: 2.837   noise: 4.309
# Iter 268/384 - Loss: 3.240   lengthscale: 2.839   noise: 4.315
# Iter 269/384 - Loss: 3.237   lengthscale: 2.841   noise: 4.322
# Iter 270/384 - Loss: 3.235   lengthscale: 2.843   noise: 4.329
# Iter 271/384 - Loss: 3.233   lengthscale: 2.845   noise: 4.335
# Iter 272/384 - Loss: 3.231   lengthscale: 2.847   noise: 4.342
# Iter 273/384 - Loss: 3.229   lengthscale: 2.849   noise: 4.348
# Iter 274/384 - Loss: 3.226   lengthscale: 2.851   noise: 4.355
# Iter 275/384 - Loss: 3.224   lengthscale: 2.853   noise: 4.361
# Iter 276/384 - Loss: 3.222   lengthscale: 2.855   noise: 4.367
# Iter 277/384 - Loss: 3.220   lengthscale: 2.857   noise: 4.374
# Iter 278/384 - Loss: 3.218   lengthscale: 2.859   noise: 4.380
# Iter 279/384 - Loss: 3.216   lengthscale: 2.861   noise: 4.387
# Iter 280/384 - Loss: 3.213   lengthscale: 2.863   noise: 4.393
# Iter 281/384 - Loss: 3.211   lengthscale: 2.865   noise: 4.399
# Iter 282/384 - Loss: 3.209   lengthscale: 2.867   noise: 4.406
# Iter 283/384 - Loss: 3.207   lengthscale: 2.869   noise: 4.412
# Iter 284/384 - Loss: 3.205   lengthscale: 2.871   noise: 4.418
# Iter 285/384 - Loss: 3.203   lengthscale: 2.872   noise: 4.425
# Iter 286/384 - Loss: 3.201   lengthscale: 2.874   noise: 4.431
# Iter 287/384 - Loss: 3.199   lengthscale: 2.876   noise: 4.437
# Iter 288/384 - Loss: 3.197   lengthscale: 2.878   noise: 4.443
# Iter 289/384 - Loss: 3.195   lengthscale: 2.880   noise: 4.449
# Iter 290/384 - Loss: 3.193   lengthscale: 2.882   noise: 4.456
# Iter 291/384 - Loss: 3.191   lengthscale: 2.884   noise: 4.462
# Iter 292/384 - Loss: 3.189   lengthscale: 2.885   noise: 4.468
# Iter 293/384 - Loss: 3.187   lengthscale: 2.887   noise: 4.474
# Iter 294/384 - Loss: 3.185   lengthscale: 2.889   noise: 4.480
# Iter 295/384 - Loss: 3.183   lengthscale: 2.891   noise: 4.486
# Iter 296/384 - Loss: 3.181   lengthscale: 2.893   noise: 4.492
# Iter 297/384 - Loss: 3.180   lengthscale: 2.895   noise: 4.499
# Iter 298/384 - Loss: 3.178   lengthscale: 2.896   noise: 4.505
# Iter 299/384 - Loss: 3.176   lengthscale: 2.898   noise: 4.511
# Iter 300/384 - Loss: 3.174   lengthscale: 2.900   noise: 4.517
# Iter 301/384 - Loss: 3.172   lengthscale: 2.902   noise: 4.523
# Iter 302/384 - Loss: 3.170   lengthscale: 2.904   noise: 4.529
# Iter 303/384 - Loss: 3.168   lengthscale: 2.905   noise: 4.535
# Iter 304/384 - Loss: 3.167   lengthscale: 2.907   noise: 4.541
# Iter 305/384 - Loss: 3.165   lengthscale: 2.909   noise: 4.547
# Iter 306/384 - Loss: 3.163   lengthscale: 2.911   noise: 4.553
# Iter 307/384 - Loss: 3.161   lengthscale: 2.912   noise: 4.558
# Iter 308/384 - Loss: 3.160   lengthscale: 2.914   noise: 4.564
# Iter 309/384 - Loss: 3.158   lengthscale: 2.916   noise: 4.570
# Iter 310/384 - Loss: 3.156   lengthscale: 2.918   noise: 4.576
# Iter 311/384 - Loss: 3.154   lengthscale: 2.919   noise: 4.582
# Iter 312/384 - Loss: 3.153   lengthscale: 2.921   noise: 4.588
# Iter 313/384 - Loss: 3.151   lengthscale: 2.923   noise: 4.594
# Iter 314/384 - Loss: 3.149   lengthscale: 2.924   noise: 4.599
# Iter 315/384 - Loss: 3.147   lengthscale: 2.926   noise: 4.605
# Iter 316/384 - Loss: 3.146   lengthscale: 2.928   noise: 4.611
# Iter 317/384 - Loss: 3.144   lengthscale: 2.929   noise: 4.617
# Iter 318/384 - Loss: 3.142   lengthscale: 2.931   noise: 4.623
# Iter 319/384 - Loss: 3.141   lengthscale: 2.933   noise: 4.628
# Iter 320/384 - Loss: 3.139   lengthscale: 2.934   noise: 4.634
# Iter 321/384 - Loss: 3.137   lengthscale: 2.936   noise: 4.640
# Iter 322/384 - Loss: 3.136   lengthscale: 2.938   noise: 4.645
# Iter 323/384 - Loss: 3.134   lengthscale: 2.939   noise: 4.651
# Iter 324/384 - Loss: 3.133   lengthscale: 2.941   noise: 4.657
# Iter 325/384 - Loss: 3.131   lengthscale: 2.943   noise: 4.662
# Iter 326/384 - Loss: 3.129   lengthscale: 2.944   noise: 4.668
# Iter 327/384 - Loss: 3.128   lengthscale: 2.946   noise: 4.674
# Iter 328/384 - Loss: 3.126   lengthscale: 2.948   noise: 4.679
# Iter 329/384 - Loss: 3.125   lengthscale: 2.949   noise: 4.685
# Iter 330/384 - Loss: 3.123   lengthscale: 2.951   noise: 4.690
# Iter 331/384 - Loss: 3.122   lengthscale: 2.952   noise: 4.696
# Iter 332/384 - Loss: 3.120   lengthscale: 2.954   noise: 4.702
# Iter 333/384 - Loss: 3.118   lengthscale: 2.956   noise: 4.707
# Iter 334/384 - Loss: 3.117   lengthscale: 2.957   noise: 4.713
# Iter 335/384 - Loss: 3.115   lengthscale: 2.959   noise: 4.718
# Iter 336/384 - Loss: 3.114   lengthscale: 2.960   noise: 4.724
# Iter 337/384 - Loss: 3.112   lengthscale: 2.962   noise: 4.729
# Iter 338/384 - Loss: 3.111   lengthscale: 2.963   noise: 4.735
# Iter 339/384 - Loss: 3.109   lengthscale: 2.965   noise: 4.740
# Iter 340/384 - Loss: 3.108   lengthscale: 2.967   noise: 4.745
# Iter 341/384 - Loss: 3.106   lengthscale: 2.968   noise: 4.751
# Iter 342/384 - Loss: 3.105   lengthscale: 2.970   noise: 4.756
# Iter 343/384 - Loss: 3.104   lengthscale: 2.971   noise: 4.762
# Iter 344/384 - Loss: 3.102   lengthscale: 2.973   noise: 4.767
# Iter 345/384 - Loss: 3.101   lengthscale: 2.974   noise: 4.772
# Iter 346/384 - Loss: 3.099   lengthscale: 2.976   noise: 4.778
# Iter 347/384 - Loss: 3.098   lengthscale: 2.977   noise: 4.783
# Iter 348/384 - Loss: 3.096   lengthscale: 2.979   noise: 4.788
# Iter 349/384 - Loss: 3.095   lengthscale: 2.980   noise: 4.794
# Iter 350/384 - Loss: 3.094   lengthscale: 2.982   noise: 4.799
# Iter 351/384 - Loss: 3.092   lengthscale: 2.983   noise: 4.804
# Iter 352/384 - Loss: 3.091   lengthscale: 2.985   noise: 4.810
# Iter 353/384 - Loss: 3.090   lengthscale: 2.986   noise: 4.815
# Iter 354/384 - Loss: 3.088   lengthscale: 2.988   noise: 4.820
# Iter 355/384 - Loss: 3.087   lengthscale: 2.989   noise: 4.825
# Iter 356/384 - Loss: 3.085   lengthscale: 2.991   noise: 4.831
# Iter 357/384 - Loss: 3.084   lengthscale: 2.992   noise: 4.836
# Iter 358/384 - Loss: 3.083   lengthscale: 2.993   noise: 4.841
# Iter 359/384 - Loss: 3.081   lengthscale: 2.995   noise: 4.846
# Iter 360/384 - Loss: 3.080   lengthscale: 2.996   noise: 4.851
# Iter 361/384 - Loss: 3.079   lengthscale: 2.998   noise: 4.857
# Iter 362/384 - Loss: 3.077   lengthscale: 2.999   noise: 4.862
# Iter 363/384 - Loss: 3.076   lengthscale: 3.001   noise: 4.867
# Iter 364/384 - Loss: 3.075   lengthscale: 3.002   noise: 4.872
# Iter 365/384 - Loss: 3.074   lengthscale: 3.003   noise: 4.877
# Iter 366/384 - Loss: 3.072   lengthscale: 3.005   noise: 4.882
# Iter 367/384 - Loss: 3.071   lengthscale: 3.006   noise: 4.887
# Iter 368/384 - Loss: 3.070   lengthscale: 3.008   noise: 4.892
# Iter 369/384 - Loss: 3.068   lengthscale: 3.009   noise: 4.898
# Iter 370/384 - Loss: 3.067   lengthscale: 3.010   noise: 4.903
# Iter 371/384 - Loss: 3.066   lengthscale: 3.012   noise: 4.908
# Iter 372/384 - Loss: 3.065   lengthscale: 3.013   noise: 4.913
# Iter 373/384 - Loss: 3.063   lengthscale: 3.015   noise: 4.918
# Iter 374/384 - Loss: 3.062   lengthscale: 3.016   noise: 4.923
# Iter 375/384 - Loss: 3.061   lengthscale: 3.017   noise: 4.928
# Iter 376/384 - Loss: 3.060   lengthscale: 3.019   noise: 4.933
# Iter 377/384 - Loss: 3.059   lengthscale: 3.020   noise: 4.938
# Iter 378/384 - Loss: 3.057   lengthscale: 3.021   noise: 4.943
# Iter 379/384 - Loss: 3.056   lengthscale: 3.023   noise: 4.948
# Iter 380/384 - Loss: 3.055   lengthscale: 3.024   noise: 4.953
# Iter 381/384 - Loss: 3.054   lengthscale: 3.025   noise: 4.957
# Iter 382/384 - Loss: 3.053   lengthscale: 3.027   noise: 4.962
# Iter 383/384 - Loss: 3.051   lengthscale: 3.028   noise: 4.967
# Iter 384/384 - Loss: 3.050   lengthscale: 3.029   noise: 4.972

# %%
model.eval()
likelihood.eval()

# Test points are regularly spaced along [0,1]
# Make predictions by feeding model through likelihood
with torch.no_grad(), gpytorch.settings.fast_pred_var():
    GP_X_test = torch.from_numpy(np.array(X_test))
    observed_pred = likelihood(model(GP_X_test))

# %%
samples = []
with torch.no_grad():
    # Initialize plot
    for i in range(training_iter):
      plt.plot(range(384),
        loss_arr,
        'b',
        linewidth=0.9,
        alpha=0.05,
        zorder=1,
        label='Samples' if i == 0 else None)
    
    plt.xlabel('x')
    plt.ylabel('y')
    plt.scatter(x=range(384), y=y_test, c='k', label='Test', zorder=2, alpha=0.5)
    plt.plot(np.array(loss_arr).mean(axis=0), label='Avg Samples', color='r', zorder=3)
    # plt.plot(model.predict(X_test), label='Single Prediction', color='g', zorder=4)

    mae_err = mean_absolute_error(y_test, observed_pred.mean.numpy())
    rmse_err = error_rms(y_test, observed_pred.mean.numpy())
    print(f'MAE Test: {mae_err}')
    print(f'RMSE Test: {rmse_err}')
    plt.xlabel(r'$x$')
    plt.ylabel(r'$y$')
    plt.legend(loc='upper left')
    plt.title(f'Gaussian Process Bayesian Neural Network with {training_iter} samples')
# Out:
# MAE Test: 1.8414558537675425
# RMSE Test: 2.5818956015450696
